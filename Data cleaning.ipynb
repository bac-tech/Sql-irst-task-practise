# %%
import pandas as pd;
from sklearn.impute import SimpleImputer

# %%
ds1=pd.read_excel("customer_data.xlsx")

# %%
ds3=pd.read_excel("customer_data.xlsx")

# %%
ds2=pd.read_excel("performance_data.xlsx")

# %%
missing_data1 = ds1.isnull().sum()

# %%
missing_data2 = ds2.isnull().sum()

# %%
missing_data3 = ds3.isnull().sum()

# %%
missing_data1
# Out:
# CustomerID                  0
# Gender                      0
# Age                         0
# Income                      5
# City                        3
# Region                      0
# Frequency_of_Purchases      0
# Average_Purchase_Amount     0
# Customer_Lifespan_Months    0
# Purchase_Channel            0
# Date_of_Purchase            0
# Churn_Status                0
# dtype: int64

# %%
missing_data2
# Out:
# CustomerID         0
# Recency            0
# Frequency_Score    0
# Monetary_Score     0
# dtype: int64

# %%
missing_data3
# Out:
# CustomerID                  0
# Gender                      0
# Age                         0
# Income                      5
# City                        3
# Region                      0
# Frequency_of_Purchases      0
# Average_Purchase_Amount     0
# Customer_Lifespan_Months    0
# Purchase_Channel            0
# Date_of_Purchase            0
# Churn_Status                0
# dtype: int64

# %%
imputer = SimpleImputer(strategy='mean')

# Fit and transform the 'Income' column (reshaped to 2D)
ds3[['Income']] = imputer.fit_transform(ds3[['Income']])

# %%
imputer1 = SimpleImputer(strategy='most_frequent')

ds3[['City']]=imputer1.fit_transform(ds3[['City']])

# %%
ds3
# Out:
#    CustomerID  Gender  Age   Income         City     Region  \
# 0        C001    Male   49  72504.0      Chicago  Northeast
# 1        C002  Female   38  40881.0     New York       West
# 2        C003    Male   17  63333.0     New York  Northeast
# 3        C004    Male   34  58030.0      Chicago    Midwest
# 4        C005    Male   30  78889.0      Houston    Midwest
# ..        ...     ...  ...      ...          ...        ...
# 76       C077  Female   38  94266.0  Los Angeles    Midwest
# 77       C078    Male   30  76887.0      Houston    Midwest
# 78       C079  Female   42  56569.0     New York       West
# 79       C080  Female   26  43931.0  Los Angeles  Northeast
# 80       C021  Female   22  41743.0  Los Angeles  Northeast
#
#     Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 0                       10             9.824100e+01                        3
# 1                       15             1.576400e+02                        4
# ...

# %%
ds3.dtypes
# Out:
# CustomerID                   object
# Gender                       object
# Age                           int64
# Income                      float64
# City                         object
# Region                       object
# Frequency_of_Purchases        int64
# Average_Purchase_Amount     float64
# Customer_Lifespan_Months     object
# Purchase_Channel             object
# Date_of_Purchase             object
# Churn_Status                 object
# dtype: object

# %%
ds3.isnull().sum()
# Out:
# CustomerID                  0
# Gender                      0
# Age                         0
# Income                      0
# City                        0
# Region                      0
# Frequency_of_Purchases      0
# Average_Purchase_Amount     0
# Customer_Lifespan_Months    0
# Purchase_Channel            0
# Date_of_Purchase            0
# Churn_Status                0
# dtype: int64

# %%
unique_values=ds3['Frequency_of_Purchases'].unique()

# %%
unique_values
# Out:
# array([10, 15,  1,  6,  3, 11,  9, 12,  8, 13, 14,  4,  7,  5,  2, 16],
#       dtype=int64)

# %%
ds3=ds3[ds3['Frequency_of_Purchases']!='inconsistent_value']

# %%
ds3
# Out:
#    CustomerID  Gender  Age   Income         City     Region  \
# 0        C001    Male   49  72504.0      Chicago  Northeast
# 1        C002  Female   38  40881.0     New York       West
# 2        C003    Male   17  63333.0     New York  Northeast
# 3        C004    Male   34  58030.0      Chicago    Midwest
# 4        C005    Male   30  78889.0      Houston    Midwest
# ..        ...     ...  ...      ...          ...        ...
# 76       C077  Female   38  94266.0  Los Angeles    Midwest
# 77       C078    Male   30  76887.0      Houston    Midwest
# 78       C079  Female   42  56569.0     New York       West
# 79       C080  Female   26  43931.0  Los Angeles  Northeast
# 80       C021  Female   22  41743.0  Los Angeles  Northeast
#
#     Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 0                       10             9.824100e+01                        3
# 1                       15             1.576400e+02                        4
# ...

# %%
ds3.head()
# Out:
#   CustomerID  Gender  Age   Income      City     Region  \
# 0       C001    Male   49  72504.0   Chicago  Northeast
# 1       C002  Female   38  40881.0  New York       West
# 2       C003    Male   17  63333.0  New York  Northeast
# 3       C004    Male   34  58030.0   Chicago    Midwest
# 4       C005    Male   30  78889.0   Houston    Midwest
#
#    Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 0                      10                   98.241                        3
# 1                      15                  157.640                        4
# 2                       1                   41.252                        1
# 3                       6                   67.329                        1
# 4                       3                   52.763                        1
#
#   Purchase_Channel Date_of_Purchase Churn_Status
# 0           Online       2022-03-05          Yes
# 1         In-store       2023-07-08          Yes
# ...

# %%
# Sorting dataset


sorted_data = ds3.sort_values(by='Income', ascending = False)
sorted_data
# Out:
#    CustomerID  Gender  Age    Income         City     Region  \
# 55       C056  Female   29  107662.0      Houston  Northeast
# 22       C023  Female   41  105186.0  Los Angeles    Midwest
# 70       C071  Female   36  103264.0  Los Angeles  Northeast
# 32       C033  Female   31   98590.0      Houston       West
# 76       C077  Female   38   94266.0  Los Angeles    Midwest
# ..        ...     ...  ...       ...          ...        ...
# 14       C015    Male   44   32500.0     New York  Northeast
# 49       C050  Female   39   29104.0      Houston    Midwest
# 10       C011  Female   53   27958.0  Los Angeles    Midwest
# 23       C024    Male   54   27660.0     New York    Midwest
# 50       C051  Female   19   15531.0      Houston    Midwest
#
#     Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 55                       3                   47.877                        1
# ...

# %%
ds3.head()
# Out:
#   CustomerID  Gender  Age   Income      City     Region  \
# 0       C001    Male   49  72504.0   Chicago  Northeast
# 1       C002  Female   38  40881.0  New York       West
# 2       C003    Male   17  63333.0  New York  Northeast
# 3       C004    Male   34  58030.0   Chicago    Midwest
# 4       C005    Male   30  78889.0   Houston    Midwest
#
#    Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 0                      10                   98.241                        3
# 1                      15                  157.640                        4
# 2                       1                   41.252                        1
# 3                       6                   67.329                        1
# 4                       3                   52.763                        1
#
#   Purchase_Channel Date_of_Purchase Churn_Status
# 0           Online       2022-03-05          Yes
# 1         In-store       2023-07-08          Yes
# ...

# %%
ds3.head()
# Out:
#   CustomerID  Gender  Age   Income      City     Region  \
# 0       C001    Male   49  72504.0   Chicago  Northeast
# 1       C002  Female   38  40881.0  New York       West
# 2       C003    Male   17  63333.0  New York  Northeast
# 3       C004    Male   34  58030.0   Chicago    Midwest
# 4       C005    Male   30  78889.0   Houston    Midwest
#
#    Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 0                      10                   98.241                        3
# 1                      15                  157.640                        4
# 2                       1                   41.252                        1
# 3                       6                   67.329                        1
# 4                       3                   52.763                        1
#
#   Purchase_Channel Date_of_Purchase Churn_Status
# 0           Online       2022-03-05          Yes
# 1         In-store       2023-07-08          Yes
# ...

# %%
filtered_data = ds3[ds3['Income'] > 25000]

# %%
filtered_data
# Out:
#    CustomerID  Gender  Age   Income         City     Region  \
# 0        C001    Male   49  72504.0      Chicago  Northeast
# 1        C002  Female   38  40881.0     New York       West
# 2        C003    Male   17  63333.0     New York  Northeast
# 3        C004    Male   34  58030.0      Chicago    Midwest
# 4        C005    Male   30  78889.0      Houston    Midwest
# ..        ...     ...  ...      ...          ...        ...
# 76       C077  Female   38  94266.0  Los Angeles    Midwest
# 77       C078    Male   30  76887.0      Houston    Midwest
# 78       C079  Female   42  56569.0     New York       West
# 79       C080  Female   26  43931.0  Los Angeles  Northeast
# 80       C021  Female   22  41743.0  Los Angeles  Northeast
#
#     Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 0                       10             9.824100e+01                        3
# 1                       15             1.576400e+02                        4
# ...

# %%
sorted_data = ds3.sort_values(by='Income', ascending = False)
sorted_data
# Out:
#    CustomerID  Gender  Age    Income         City     Region  \
# 55       C056  Female   29  107662.0      Houston  Northeast
# 22       C023  Female   41  105186.0  Los Angeles    Midwest
# 70       C071  Female   36  103264.0  Los Angeles  Northeast
# 32       C033  Female   31   98590.0      Houston       West
# 76       C077  Female   38   94266.0  Los Angeles    Midwest
# ..        ...     ...  ...       ...          ...        ...
# 14       C015    Male   44   32500.0     New York  Northeast
# 49       C050  Female   39   29104.0      Houston    Midwest
# 10       C011  Female   53   27958.0  Los Angeles    Midwest
# 23       C024    Male   54   27660.0     New York    Midwest
# 50       C051  Female   19   15531.0      Houston    Midwest
#
#     Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 55                       3                   47.877                        1
# ...

# %%
 filtered_data = ds3.query('Income > 20000'  or 'Income > 25000')
filtered_data
# Out:
#    CustomerID  Gender  Age   Income         City     Region  \
# 0        C001    Male   49  72504.0      Chicago  Northeast
# 1        C002  Female   38  40881.0     New York       West
# 2        C003    Male   17  63333.0     New York  Northeast
# 3        C004    Male   34  58030.0      Chicago    Midwest
# 4        C005    Male   30  78889.0      Houston    Midwest
# ..        ...     ...  ...      ...          ...        ...
# 76       C077  Female   38  94266.0  Los Angeles    Midwest
# 77       C078    Male   30  76887.0      Houston    Midwest
# 78       C079  Female   42  56569.0     New York       West
# 79       C080  Female   26  43931.0  Los Angeles  Northeast
# 80       C021  Female   22  41743.0  Los Angeles  Northeast
#
#     Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 0                       10             9.824100e+01                        3
# 1                       15             1.576400e+02                        4
# ...

# %%
filtered_data = ds3[ds3['Region'].isin(['West', 'Northeast'])]
filtered_data
# Out:
#    CustomerID  Gender  Age         Income         City     Region  \
# 0        C001    Male   49   72504.000000      Chicago  Northeast
# 1        C002  Female   38   40881.000000     New York       West
# 2        C003    Male   17   63333.000000     New York  Northeast
# 6        C007  Female   35   60349.000000      Houston  Northeast
# 7        C008    Male   38   38401.000000      Houston       West
# 8        C009    Male   44   73105.000000  Los Angeles  Northeast
# 9        C010  Female   47   65341.000000     New York  Northeast
# 12       C013  Female   24   45208.000000      Chicago       West
# 14       C015    Male   44   32500.000000     New York  Northeast
# 16       C017  Female   26   75726.000000     New York       West
# 18       C019    Male   32   41111.000000  Los Angeles       West
# 20       C021  Female   22   41743.000000  Los Angeles  Northeast
# 24       C025    Male   27   45239.000000  Los Angeles       West
# ...

# %%
ds3.loc[0:4, 'CustomerID':'Income']
# Out:
#   CustomerID  Gender  Age   Income
# 0       C001    Male   49  72504.0
# 1       C002  Female   38  40881.0
# 2       C003    Male   17  63333.0
# 3       C004    Male   34  58030.0
# 4       C005    Male   30  78889.0

# %%
filtered_data1 = ds3[(ds3['Income']>45) | (ds3['Income']<= 45000)]

# %%
filtered_data1
# Out:
#    CustomerID  Gender  Age   Income         City     Region  \
# 0        C001    Male   49  72504.0      Chicago  Northeast
# 1        C002  Female   38  40881.0     New York       West
# 2        C003    Male   17  63333.0     New York  Northeast
# 3        C004    Male   34  58030.0      Chicago    Midwest
# 4        C005    Male   30  78889.0      Houston    Midwest
# ..        ...     ...  ...      ...          ...        ...
# 76       C077  Female   38  94266.0  Los Angeles    Midwest
# 77       C078    Male   30  76887.0      Houston    Midwest
# 78       C079  Female   42  56569.0     New York       West
# 79       C080  Female   26  43931.0  Los Angeles  Northeast
# 80       C021  Female   22  41743.0  Los Angeles  Northeast
#
#     Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 0                       10             9.824100e+01                        3
# 1                       15             1.576400e+02                        4
# ...
